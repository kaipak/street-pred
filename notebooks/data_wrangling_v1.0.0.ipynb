# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = [12, 8]
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/processed/stage3_sentiment.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                             songid  \
# 0           0                      Gin And JuiceSnoop Doggy Dogg
# 1           1   Holidae InChingy Featuring Ludacris & Snoop Dogg
# 2           2                                Get AwayBobby Brown
# 3           3                             Fantastic VoyageCoolio
# 4           4  I'm On OneDJ Khaled Featuring Drake, Rick Ross...
#
#          spotify_track_id                                       artist_genre  \
# 0  0WKYRFtH6KKbaNWjsxqm70  ['g funk', 'gangster rap', 'hip hop', 'pop rap...
# 1  0FmCLEHfINGqwlyzvklNqy  ['crunk', 'dance pop', 'dirty south rap', 'gan...
# 2  62cC8knNydvmC1JPZExWTD  ['dance pop', 'funk', 'hip hop', 'new jack swi...
# 3  3QlTzofanSqDWywxEzGGE2  ['g funk', 'gangster rap', 'hip hop', 'rap', '...
# 4  608a1wIsSd5KzMEqm1O7w3  ['dance pop', 'hip hop', 'miami hip hop', 'pop...
#
#    spotify_track_duration_ms  spotify_track_popularity  danceability  energy  \
# ...

# %%
def label_track(row):
    if (row['weeks_on_chart'] >= 20) & (row['peak_position'] <= 20):
        return(True)
    else:
        return(False)

# %%
df['hit'] = df.apply(label_track, axis=1)

# %%
df.head()
# Out:
#                                               songid        spotify_track_id  \
# 0                      Gin And JuiceSnoop Doggy Dogg  0WKYRFtH6KKbaNWjsxqm70
# 1   Holidae InChingy Featuring Ludacris & Snoop Dogg  0FmCLEHfINGqwlyzvklNqy
# 2                                Get AwayBobby Brown  62cC8knNydvmC1JPZExWTD
# 3                             Fantastic VoyageCoolio  3QlTzofanSqDWywxEzGGE2
# 4  I'm On OneDJ Khaled Featuring Drake, Rick Ross...  608a1wIsSd5KzMEqm1O7w3
#
#                                         artist_genre  \
# 0  ['g funk', 'gangster rap', 'hip hop', 'pop rap...
# 1  ['crunk', 'dance pop', 'dirty south rap', 'gan...
# 2  ['dance pop', 'funk', 'hip hop', 'new jack swi...
# 3  ['g funk', 'gangster rap', 'hip hop', 'rap', '...
# 4  ['dance pop', 'hip hop', 'miami hip hop', 'pop...
#
#    spotify_track_duration_ms  spotify_track_popularity  danceability  energy  \
# 0                   211493.0                      74.0         0.549   0.853
# ...

# %%
df.groupby('hit').size().reset_index()
# Out:
#      hit     0
# 0  False  1779
# 1   True   465

# %%
df.to_csv('../data/processed/stage4_moreNLP_labels.csv')

# %%
sns.regplot(data=df, x='acousticness', y='spotify_track_popularity')

# %%
df.drop(columns='Unnamed: 0', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-bc3ab6f550fe> in <module>
# ----> 1 df.drop(columns='Unnamed: 0', inplace=True)
#
# ~/anaconda3/envs/kai/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/anaconda3/envs/kai/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df.to_csv('../data/processed/stage4_moreNLP_labels.csv')

# %%
df.columns
# Out:
# Index(['songid', 'spotify_track_id', 'artist_genre',
#        'spotify_track_duration_ms', 'spotify_track_popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'performer', 'song', 'lyrics', 'peak_position', 'weeks_on_chart',
#        'instance', 'lyrics_proc', 'word_count', 'vocab_count', 'lex_div',
#        'sentiment_pos', 'sentiment_neg', 'sentiment_neu', 'sentiment_val',
#        'weekid', 'year', 'month', 'hit'],
#       dtype='object')
