# %% [markdown]
# # Exploratory Data Analysis
# Datasets derived from Spotify API which has some kind of pre-rolled statistics about the music in top 100. Drawback here obviously that we don't necessarily know how they calculate these. Maybe something to consider for version 2.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys
sys.path.append('../src')
import dataset

# %%
df_spotify = pd.read_csv('../data/raw/hot_100_audio_features.csv')
df_bb = pd.read_csv('../data/raw/hot_stuff_2.csv')
df_spotify.shape
# Out:
# (28090, 17)

# %%
df_af, df_bb = dataset.process_datasets('../data/raw/hot_100_audio_features.csv',
                         '../data/raw/hot_stuff_2.csv',
                         'foo')

# %%
df_bb.sort_values(by='weekid', ascending=False).head()
# Out:
#                                                       url      weekid  \
# 291198  https://www.billboard.com/charts/hot-100/2019-...  2019-06-22
# 120370  https://www.billboard.com/charts/hot-100/2019-...  2019-06-22
# 288397  https://www.billboard.com/charts/hot-100/2019-...  2019-06-22
# 133526  https://www.billboard.com/charts/hot-100/2019-...  2019-06-22
# 153582  https://www.billboard.com/charts/hot-100/2019-...  2019-06-22
#
#         week_position              song         performer  \
# 291198             35            Better            Khalid
# 120370             47             Press           Cardi B
# 288397             13  Sweet But Psycho           Ava Max
# 133526             46       Good As You        Kane Brown
# 153582             50           Go Loko  YG, Tyga & Jon Z
#
#                          songid  instance  previous_week_position  \
# 291198             BetterKhalid         1                    34.0
# 120370             PressCardi B         1                    16.0
# 288397  Sweet But PsychoAva Max         1                    10.0
# 133526    Good As YouKane Brown         1                    41.0
# 153582  Go LokoYG, Tyga & Jon Z         1                    50.0
#
#         peak_position  weeks_on_chart               songkey
# 291198              8              39          betterkhalid
# 120370             16               2           presscardib
# 288397             10              26  sweetbutpsychoavamax
# 133526             36              16    goodasyoukanebrown
# 153582             50               6      golokoygtygajonz

# %%
sns.distplot(df_spotify.dropna().spotify_track_popularity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f0a0d08381a6> in <module>
# ----> 1 sns.distplot(df_spotify.dropna().spotify_track_popularity)
#
# NameError: name 'df_spotify' is not defined

# %%
len(pd.unique(df_bb.performer))
# Out:
# 9553

# %%
foo = df_bb['songid']
foo = foo.str.lower()
foo = foo.str.replace(r'[^a-zA-Z\d]+', '')
foo = foo.str.strip()
foo
# Out:
# 0                              dontwannafallinlovejanechild
# 1                              dontwannafallinlovejanechild
# 2                              dontwannafallinlovejanechild
# 3                              dontwannafallinlovejanechild
# 4                              dontwannafallinlovejanechild
#                                 ...
# 317790                          thatsallyougottadobrendalee
# 317791                              simonsays1910fruitgumco
# 317792                                    shesaladytomjones
# 317793                                  ringmybellanitaward
# 317794    sanfranciscobesuretowearflowersinyourhairscott...
# Name: songid, Length: 317795, dtype: object

# %%
df_bb['songid']
# Out:
# 0                        Don't Wanna Fall In LoveJane Child
# 1                        Don't Wanna Fall In LoveJane Child
# 2                        Don't Wanna Fall In LoveJane Child
# 3                        Don't Wanna Fall In LoveJane Child
# 4                        Don't Wanna Fall In LoveJane Child
#                                 ...
# 317790                    That's All You Gotta DoBrenda Lee
# 317791                          Simon Says1910 Fruitgum Co.
# 317792                                She's A LadyTom Jones
# 317793                               Ring My BellAnita Ward
# 317794    San Francisco (Be Sure To Wear Flowers In Your...
# Name: songid, Length: 317795, dtype: object

# %%
foo
# Out:
# 0                              dontwannafallinlovejanechild
# 1                              dontwannafallinlovejanechild
# 2                              dontwannafallinlovejanechild
# 3                              dontwannafallinlovejanechild
# 4                              dontwannafallinlovejanechild
#                                 ...
# 317790                          thatsallyougottadobrendalee
# 317791                              simonsays1910fruitgumco
# 317792                                    shesaladytomjones
# 317793                                  ringmybellanitaward
# 317794    sanfranciscobesuretowearflowersinyourhairscott...
# Name: songid, Length: 317795, dtype: object

# %%
df_lyrics = pd.read_csv('../data/raw/lyrics.csv')

# %%
df_lyrics['songkey'] = df_lyrics['artist'] + df_lyrics['song']
df_lyrics['songkey'] = df_lyrics['songkey'].str.replace(r'-', '')
df_lyrics['songkey'] = df_lyrics['songkey'].str.strip()

# %%
df_lyrics.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics  \
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...
#
#                       songkey
# 0      beyonceknowlesegoremix
# 1    beyonceknowlesthentellme
# 2       beyonceknowleshonesty
# 3  beyonceknowlesyouaremyrock
# 4  beyonceknowlesblackculture

# %%
df_lyrics.dropna(inplace=True)

# %%
df_lyrics[df_lyrics['songkey'].str.contains('snoop')]
# Out:
#          index                                               song  year  \
# 32294    32294  winter-wonderland-here-comes-santa-claus-and-s...  2015
# 65064    65064                                 snoopy-s-christmas  2006
# 106299  106299                    sweat-snoop-dogg-vsdavid-guetta  2011
# 127076  127076               2-of-amerikaz-most-wanted-snoop-dogg  2006
# 152024  152024                                story-by-snoop-lion  2012
# 245206  245206                    what-s-my-name-snoop-doggy-dogg  2010
# 245209  245209                                 lay-low-snoop-dogg  2010
# 349007  349007                  one-way-or-another-snoops-version  2006
#
#                   artist          genre  \
# 32294      anna-kendrick            Pop
# 65064   christmas-carols  Not Available
# 106299      david-guetta     Electronic
# 127076              2pac        Hip-Hop
# 152024          big-sean        Hip-Hop
# 245206            dr-dre        Hip-Hop
# 245209            dr-dre        Hip-Hop
# 349007           blondie           Rock
#
#                                                    lyrics  \
# 32294   Sleigh bells ring, are you listening?\nIn the ...
# 65064   O Tannenbaum, O Tannenbaum,\nDu kannst mir seh...
# 106299  Dig Snoop Dogg\nCan you be my doctor?\nCan you...
# 127076  Up outta there\nAin't nuthin' but a gangster p...
# 152024  Ye it's so cold in the motherfucking D\nI'm ta...
# 245206  EeeyiyiyiyiyahtheDoggPound'sinthehou-owwse (th...
# 245209  [Snoop Dogg]\nYo what's Crip-a-lat'n? Dis big ...
# 349007  One way or another, I'm gonna find ya'\nI'm go...
#
#                                                   songkey
# 32294   annakendrickwinterwonderlandherecomessantaclau...
# 65064                     christmascarolssnoopyschristmas
# 106299             davidguettasweatsnoopdoggvsdavidguetta
# 127076                 2pac2ofamerikazmostwantedsnoopdogg
# 152024                            bigseanstorybysnooplion
# 245206                     drdrewhatsmynamesnoopdoggydogg
# 245209                               drdrelaylowsnoopdogg
# 349007                blondieonewayoranothersnoopsversion

# %%
df_af.shape
# Out:
# (28090, 18)

# %%
foo = df_af.merge(df_lyrics, how='left')

# %%
foo.loc[foo['artist_genre'].str.contains('hip hop')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-82b5da12f754> in <module>
# ----> 1 foo.loc[foo['artist_genre'].str.contains('hip hop')]
#
# ~/anaconda3/envs/kai/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/envs/kai/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1796             self._validate_key(key, axis)
#    1797             return self._get_slice_axis(key, axis=axis)
# -> 1798         elif com.is_bool_indexer(key):
#    1799             return self._getbool_axis(key, axis=axis)
#    1800         elif is_list_like_indexer(key):
#
# ~/anaconda3/envs/kai/lib/python3.7/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     128             if not lib.is_bool_array(key):
#     129                 if isna(key).any():
# --> 130                     raise ValueError(na_msg)
#     131                 return False
#     132             return True
#
# ValueError: cannot index with vector containing NA / NaN values

# %%
foo.dropna()
# Out:
#               songid        spotify_track_id  \
# 3873  DominoJessie J  6MAdEUilV2p9RQUqE5bMAK
#
#                                            artist_genre  \
# 3873  ['australian pop', 'dance pop', 'pop', 'pop ra...
#
#       spotify_track_duration_ms  spotify_track_popularity  danceability  \
# 3873                   231693.0                      63.0         0.757
#
#       energy  key  loudness  mode  ...  valence    tempo  time_signature  \
# 3873   0.547  7.0    -4.573  True  ...    0.793  126.977             4.0
#
#             songkey     index      song    year  artist    genre  \
# 3873  dominojessiej  311048.0  jessie-j  2013.0  domino  Hip-Hop
#
#                                                  lyrics
# 3873  I'm feeling sexy and free\nLike glitters raini...
#
# [1 rows x 24 columns]

# %%
import lyricsgenius

# %%
token = 'QOkPNsgDXBxuex27C6TWN2R0EQJ5pol4baxhYde0rxlGoAZ2Hfyb3OpLXm52e8ta'
genius = lyricsgenius.Genius(token)

# %%
song = genius.search_song('gin and juice', 'snoop')
# Out:
# Searching for "gin and juice" by snoop...
# Done.

# %%
artist = genius.search_artist('Snoop ', max_songs=1)
# Out:
# Searching for songs by Snoop...
#
# Changing artist name to 'Snoop Dogg'
# Song 1: "Gin and Juice"
#
# Reached user-specified song limit (1).
# Done. Found 1 songs.

# %%
song.lyrics
# Out:
# "[Intro: Daz Dillinger & (Snoop Dogg)]\n(Ugh) Ha-ha-ha, I'm serious, nigga\nOne of y'all niggas got some bad motherfuckin' breath\n(Oh, man) Aye, baby, aye, baby, (shit) aye, baby\nGet some bubblegum in this motherfucker or somethin'\nAye, nigga, get somethin' to eat, dog\nAye, nigga, study long, study wrong, nigga\n\n[Verse 1: Snoop Dogg]\nWith so much drama in the L-B-C\nIt's kind of hard bein' Snoop D-O-double-G\nBut I, somehow, some way\nKeep comin' up with funky-ass shit, like, every single day\nMay I kick a little something for the G's\nAnd make a few ends as I breach through?\nTwo in the mornin' and the party's still jumpin'\n‘Cause my momma ain't home\nI got bitches in the livin' room gettin' it on\nAnd they ain't leavin' till six in the mornin'\nSo what you wanna do?\nShit, I got a pocket full of rubbers and my homeboys do too\nSo turn off the lights and close the doors\nBut (but what?) we don't love them hoes, yeah\nSo we gon' smoke a ounce to this\nG's up, hoes down, while you motherfuckers bounce to this\n\n[Chorus: Daz Dillinger & Lil David Ruffin, Snoop Dogg & Daz Dillinger]\nRollin' down the street, smokin' indo\nSippin' on gin and juice,laid back\nWith my mind on my money\nAnd my money on my mind\nRollin' down the street, smokin' indo\nSippin' on gin and juice, laid back\nWith my mind on my money\nAnd my money on my mind\n\n[Verse 2: Snoop Dogg]\nNow that I got me some Seagram's gin\nEverybody got they cups, but they ain't chipped in\nNow this type of shit happens all the time\nYou got to get yours but, fool, I gotta get mine\nEverything is fine when you listening to the D-O-G\nI got the cultivating music that be captivating he\nWho listens to the words that I speak\nAs I take me a drink to the middle of the street\nAnd get to mackin' to this bitch named Sadie (Sadie?)\nShe used to be the homeboy's lady (Oh, that bitch)\n80 degrees, when I tell that bitch please\nRaise up off these N-U-T's, ‘cause you gets none of these\nAt ease, as I mob with the Dogg Pound\nFeel the breeze beyotch, I'm just…\n\n[Chorus: Snoop Dogg & Daz Dillinger]\nRollin' down the street, smokin' indo\nSippin' on gin and juice, laid back\nWith my mind on my money\nAnd my money on my mind\nRollin' down the street, smokin' indo\nSippin' on gin and juice, laid back\nWith my mind on my money\nAnd my money on my mind\n\n[Verse 3: Snoop Dogg]\nLater on that day, my homie Dr. Dre\nCame through with a gang of Tanqueray\nAnd a fat ass J of some bubonic chronic\nThat made me choke; shit, this ain't no joke\nI had to back up off of it and sit my cup down\nTanqueray and chronic, yeah, I'm fucked up now\nBut it ain't no stoppin', I'm still poppin'\nDre got some bitches from the city of Compton\nTo serve me; not with a cherry on top\n‘Cause when I bust my nut I'm raising up off the cot\nDon't get upset, girl, that's just how it goes\nI don't love you, hoes, I'm out the door, and I'll be...\n\n[Chorus: Snoop Dogg & Daz Dillinger]\nRollin' down the street, smokin' indo\nSippin' on gin and juice, laid back\nWith my mind on my money\nAnd my money on my mind\nRollin' down the street, smokin' indo\nSippin' on gin and juice, laid back\nWith my mind on my money\nAnd my money on my mind\nRollin' down the street, smokin' indo\nSippin' on gin and juice, beyotch\nWith my mind on my money\nAnd my money on my mind\nRollin' down the street, smokin' indo\nSippin' on gin and juice, beyotch\nWith my mind on my money\nAnd my money on my mind"

# %%
song = genius.search_song('g thang', 'dr dre')
# Out:
# Searching for "g thang" by dr dre...
# Done.

# %%
song.lyrics
# Out:
# "[Produced by Dr. Dre]\n\n[Verse 1: Snoop Dogg & Dr. Dre]\nOne, two, three and to the four\nSnoop Doggy Dogg and Dr. Dre is at the door\nReady to make an entrance so back on up\n‘Cause you know we're 'bout to rip shit up\nGive me the microphone first so I can bust like a bubble\nCompton and Long Beach together, now you know you in trouble\nAin't nuthin' but a G thang, baby\nTwo loc'ed out niggas so we're crazy\nDeath Row is the label that pays me\nUnfadeable so please don't try to fade this (Hell yeah)\nBut um, back to the lecture at hand\nPerfection is perfected so I'ma let 'em understand\nFrom a young G's perspective\nAnd before me dig out a bitch I have to find a contraceptive\nYou never know, she could be earnin' her man\nAnd learnin' her man, and at the same time burnin' her man\nNow, you know I ain't with that shit, Lieutenant\nAin't no pussy good enough to get burnt while I'm up in it (Yeah)\nAnd that's realer than Real-Deal Holyfield\nAnd now you hookers and hoes know how I feel\nWell, if it's good enough to get broke off a proper chunk\nI'll take a small piece of some of that funky stuff\n\n[Hook: Both & Snoop Dogg]\nIt's like this and like that and like this and a\nIt's like that and like this and like that and a\nIt's like this and like that and like this and a\nDre, creep to the mic like a phantom\n\n[Verse 2: Dr. Dre]\nWell, I'm peepin' and I'm creepin' and I'm creepin'\nBut I damn near got caught ‘cause my beeper kept beepin'\nNow it's time for me to make my impression felt\nSo sit back, relax, and strap on your seat belt\nYou never been on a ride like this befo'\nWith a producer who can rap and control the maestro\nAt the same time with the dope rhyme that I kick\nYou know and I know, I flow some old funky shit\nTo add to my collection, the selection symbolizes dope\nTake a toke, but don't choke\nIf you do, you'll have no clue\nOn what me and my homie Snoop Dogg came to do\n\n[Hook: Both & Dr. Dre & Snoop Dogg]\nIt's like this and like that and like this and a\nIt's like that and like this and like that and a\nIt's like this, and who gives a fuck about those?\nSo just chill 'til the next episode\n\n[Refrain: Kid Dynamite, Public Enemy & Congress Alley]\nYou’ve got the feeling\nRock the other side\nYou’ve got the feeling (Yeah, yeah)\n\n[Verse 3: Snoop Dogg & Dr. Dre & Both]\nFallin' back on that ass with a hellafied gangsta lean\nGettin' funky on the mic like a old batch of collard greens\nIt's the capital S, oh yes, I'm fresh, N double-O, P\nD, O, double-G, Y, D, O, double-G, you see\nShowin' much flex when it's time to wreck a mic\nPimpin' hoes and clockin' a grip like my name was Dolemite\nYeah, and it don't quit\nI think they in the mood for some motherfuckin' G shit (Hell yeah!)\nSo, Dre (What up, Dogg?)\nGotta give 'em what they want (What's that, G?)\nWe gotta break 'em off somethin' (Hell yeah)\nAnd it's gotta be bumpin' (City of Compton)\n\n[Verse 4: Dr. Dre]\nIs where it takes place, so when asked, your attention\nMobbin' like a motherfucker but I ain't lynchin'\nDroppin' the funky shit that's makin' the sucker niggas mumble\nWhen I'm on the mic, it's like a cookie: they all crumble\nTry to get close and your ass'll get smacked\nMy motherfuckin' homie Doggy Dogg has got my back\nNever let me slip, ‘cause if I slip, then I'm slippin'\nBut if I got my nina, then you know I'm straight trippin'\nAnd I'ma continue to put the rap down, put the mack down\nAnd if you bitches talk shit, I have to put the smack down\nYeah, and you don't stop\nI told ya I'm just like a clock when I tick and I tock\nBut I'm never off, always on to the break of dawn\nC-O-M-P-T-O-N and the city they call Long Beach\nPuttin' the shit together\nLike my nigga D.O.C., no one can do it better\n\n[Hook: Both & Dr. Dre & Snoop Dogg]\nLike this, that and this and a\nIt's like that and like this and like that and a\nIt's like this, and who gives a fuck about those?\nSo just chill 'til the next episode\n\n[Refrain: Kid Dynamite, Public Enemy  ...

# %%
df_bb.head()
# Out:
#                                                  url      weekid  \
# 0  http://www.billboard.com/charts/hot-100/1990-0...  1990-02-10
# 1  http://www.billboard.com/charts/hot-100/1990-0...  1990-02-17
# 2  http://www.billboard.com/charts/hot-100/1990-0...  1990-02-24
# 3  http://www.billboard.com/charts/hot-100/1990-0...  1990-03-03
# 4  http://www.billboard.com/charts/hot-100/1990-0...  1990-03-10
#
#    week_position                      song   performer  \
# 0             75  Don't Wanna Fall In Love  Jane Child
# 1             53  Don't Wanna Fall In Love  Jane Child
# 2             43  Don't Wanna Fall In Love  Jane Child
# 3             37  Don't Wanna Fall In Love  Jane Child
# 4             27  Don't Wanna Fall In Love  Jane Child
#
#                                songid  instance  previous_week_position  \
# 0  Don't Wanna Fall In LoveJane Child         1                     NaN
# 1  Don't Wanna Fall In LoveJane Child         1                    75.0
# 2  Don't Wanna Fall In LoveJane Child         1                    53.0
# 3  Don't Wanna Fall In LoveJane Child         1                    43.0
# 4  Don't Wanna Fall In LoveJane Child         1                    37.0
#
#    peak_position  weeks_on_chart                       songkey
# 0             75               1  dontwannafallinlovejanechild
# 1             53               2  dontwannafallinlovejanechild
# 2             43               3  dontwannafallinlovejanechild
# 3             37               4  dontwannafallinlovejanechild
# 4             27               5  dontwannafallinlovejanechild

# %%
df_bb_10 = df_bb.sample(10)

# %%
df_bb_10
# Out:
#                                                       url      weekid  \
# 188639  http://www.billboard.com/charts/hot-100/2011-1...  2011-11-26
# 246920  http://www.billboard.com/charts/hot-100/1977-0...  1977-02-19
# 213705  http://www.billboard.com/charts/hot-100/1997-0...  1997-04-05
# 85737   http://www.billboard.com/charts/hot-100/1964-0...  1964-09-12
# 124890  http://www.billboard.com/charts/hot-100/2015-0...  2015-07-25
# 47074   http://www.billboard.com/charts/hot-100/1991-0...  1991-09-14
# 199264  http://www.billboard.com/charts/hot-100/1991-1...  1991-10-12
# 106124  http://www.billboard.com/charts/hot-100/1981-0...  1981-08-22
# 273289  http://www.billboard.com/charts/hot-100/2015-0...  2015-01-17
# 257005  http://www.billboard.com/charts/hot-100/2013-0...  2013-07-20
#
#         week_position                                 song  \
# 188639             97  The Adventures Of Rain Dance Maggie
# 246920             13                      Year Of The Cat
# 213705              1            Can't Nobody Hold Me Down
# 85737              71                      Johnny B. Goode
# 124890             77                          Do It Again
# 47074              12                   Love Of A Lifetime
# 199264             56             Sometimes (It's A Bitch)
# 106124             80                             La-Di-Da
# 273289              8                 I'm Not The Only One
# 257005             29                  When I Was Your Man
#
#                                    performer  \
# 188639                 Red Hot Chili Peppers
# 246920                            Al Stewart
# 213705           Puff Daddy (Featuring Mase)
# 85737                           Dion Di Muci
# 124890  Pia Mia Featuring Chris Brown & Tyga
# 47074                              Firehouse
# 199264                          Stevie Nicks
# 106124                              Sad Cafe
# 273289                             Sam Smith
# 257005                            Bruno Mars
#
#                                                    songid  instance  \
# 188639  The Adventures Of Rain Dance MaggieRed Hot Chi...         1
# 246920                          Year Of The CatAl Stewart         1
# 213705  Can't Nobody Hold Me DownPuff Daddy (Featuring...         1
# 85737                         Johnny B. GoodeDion Di Muci         1
# 124890    Do It AgainPia Mia Featuring Chris Brown & Tyga         1
# 47074                         Love Of A LifetimeFirehouse         1
# 199264               Sometimes (It's A Bitch)Stevie Nicks         1
# 106124                                   La-Di-DaSad Cafe         1
# 273289                      I'm Not The Only OneSam Smith         2
# 257005                      When I Was Your ManBruno Mars         3
#
#         previous_week_position  peak_position  weeks_on_chart  \
# 188639                    89.0             38              17
# 246920                    15.0             13              11
# 213705                     1.0              1              11
# 85737                     71.0             71               4
# 124890                    86.0             77               2
# 47074                     18.0             12              12
# 199264                    57.0             56               6
# 106124                    90.0             80               2
# 273289                     6.0              5              18
# 257005                    26.0              1              29
#
#                                                  songkey
# 188639  theadventuresofraindancemaggieredhotchilipeppers
# 246920                             yearofthecatalstewart
# 213705        cantnobodyholdmedownpuffdaddyfeaturingmase
# 85737                             johnnybgoodediondimuci
# 124890            doitagainpiamiafeaturingchrisbrowntyga
# 47074                           loveofalifetimefirehouse
# 199264                     sometimesitsabitchstevienicks
# 106124                                     ladidasadcafe
# 273289                           imnottheonlyonesamsmith
# 257005                          wheniwasyourmanbrunomars

# %%
df_bb_10['lyrics'] = df_bb_10.apply(get_lyrics, axis=1)
# Out:
# Searching for "Adam Lambert" by If I Had You...
# Done.
# Searching for "Rod Stewart" by Oh! No Not My Baby...
# Done.
# Searching for "Kenny Chesney" by There Goes My Life...
# Done.
# Searching for "Hillsong UNITED" by Oceans (Where Feet May Fail)...
# Done.
# Searching for "Flo Rida" by Good Feeling...
# Done.
# Searching for "Omarion" by Touch...
# Done.
# Searching for "Jerry Wallace" by In The Misty Moonlight...
# Done.
# Searching for "Uncle Kracker" by Follow Me...
# Done.
# Searching for "Fats Domino" by My Girl Josephine...
# Done.
# Searching for "The Beatles" by I Am The Walrus...
# Done.

# %%
def get_lyrics(row):
    song = genius.search_song(row.performer, row.song)
    return song.lyrics

# %%
df_bb_10
# Out:
#                                                       url      weekid  \
# 70723   http://www.billboard.com/charts/hot-100/1990-0...  1990-01-27
# 166334  https://www.billboard.com/charts/hot-100/2018-...  2018-09-15
# 72153   http://www.billboard.com/charts/hot-100/1959-0...  1959-05-23
# 252883  http://www.billboard.com/charts/hot-100/1985-0...  1985-06-08
# 85958   http://www.billboard.com/charts/hot-100/1994-0...  1994-07-16
# 281435  http://www.billboard.com/charts/hot-100/2000-0...  2000-09-23
# 65824   http://www.billboard.com/charts/hot-100/2003-1...  2003-10-18
# 40495   http://www.billboard.com/charts/hot-100/1990-1...  1990-10-27
# 259691  http://www.billboard.com/charts/hot-100/1966-1...  1966-10-08
# 100037  http://www.billboard.com/charts/hot-100/1970-0...  1970-02-28
#
#         week_position                                 song          performer  \
# 70723              52                      Electric Boogie   Marcia Griffiths
# 166334             68                          Blue Tacoma  Russell Dickerson
# 72153              87            The Battle Of New Orleans      Vaughn Monroe
# 252883             56                     What About Love?              Heart
# 85958              72                        It's Over Now   Cause And Effect
# 281435             68                        Open My Heart      Yolanda Adams
# 65824              99                           Find A Way              Dwele
# 40495              66                       Love Is A Rock     REO Speedwagon
# 259691             95                    The Wheel Of Hurt   Margaret Whiting
# 100037             28  Love Grows (Where My Rosemary Goes)  Edison Lighthouse
#
#                                                    songid  instance  \
# 70723                     Electric BoogieMarcia Griffiths         1
# 166334                       Blue TacomaRussell Dickerson         1
# 72153              The Battle Of New OrleansVaughn Monroe         1
# 252883                              What About Love?Heart         1
# 85958                       It's Over NowCause And Effect         1
# 281435                         Open My HeartYolanda Adams         1
# 65824                                     Find A WayDwele         1
# 40495                        Love Is A RockREO Speedwagon         1
# 259691                  The Wheel Of HurtMargaret Whiting         1
# 100037  Love Grows (Where My Rosemary Goes)Edison Ligh...         1
#
#         previous_week_position  peak_position  weeks_on_chart  \
# 70723                     51.0             51               8
# 166334                    68.0             68               3
# 72153                      NaN             87               1
# 252883                    73.0             56               2
# 85958                     80.0             72               4
# 281435                    69.0             68               5
# 65824                    100.0             96               5
# 40495                     74.0             66               3
# 259691                     NaN             95               1
# 100037                    68.0             28               2
#
#                                              songkey  \
# 70723                  electricboogiemarciagriffiths
# 166334                    bluetacomarusselldickerson
# 72153              thebattleofneworleansvaughnmonroe
# 252883                            whataboutloveheart
# 85958                       itsovernowcauseandeffect
# 281435                       openmyheartyolandaadams
# 65824                                  findawaydwele
# 40495                       loveisarockreospeedwagon
# 259691                 thewheelofhurtmargaretwhiting
# 100037  lovegrowswheremyrosemarygoesedisonlighthouse
#
#                                                    lyrics
# 70723   It's Electric!\n\nYou can't see it\n[It's elec...
# 166334  [Intro]\nBlue Tacoma, California\nRays of gold...
# 72153   In 1814, we took a little trip\nAlong with Col...
# 252883  I've been lonely\nI've been waiting for you\nI...
# 85958   I guess it's over now\nI think we've seen the ...
# 281435  [Verse 1:]\nAlone in a room\nIt's just me and ...
# 65824   It used to be...we would be...the best of all ...
# 40495   My love is a rock, an immovable force\nAnywher...
# 259691  OPENING CREDITS\n\nCUT TO: TAXI\n\nDeadpool si...
# 100037  She ain't got no money\nHer clothes are kinda ...

# %%
from multiprocessing import  Pool
from functools import partial
import numpy as np

def parallelize(data, func, num_of_processes=8):
    data_split = np.array_split(data, num_of_processes)
    pool = Pool(num_of_processes)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data

def run_on_subset(func, data_subset):
    return data_subset.apply(func, axis=1)

def parallelize_on_rows(data, func, num_of_processes=8):
    return parallelize(data, partial(run_on_subset, func), num_of_processes)

# %%
parallelize_on_rows(df_bb_10, get_lyrics, num_of_processes=4)
# Out:
# Searching for "Sam Smith" by I'm Not The Only One...
# Searching for "Stevie Nicks" by Sometimes (It's A Bitch)...
# Searching for "Dion Di Muci" by Johnny B. Goode...
# Searching for "Red Hot Chili Peppers" by The Adventures Of Rain Dance Maggie...
# Done.
# Searching for "Pia Mia Featuring Chris Brown & Tyga" by Do It Again...
# Done.
# Searching for "Bruno Mars" by When I Was Your Man...
# Done.
# Searching for "Al Stewart" by Year Of The Cat...
# Done.
# Searching for "Puff Daddy (Featuring Mase)" by Can't Nobody Hold Me Down...
# Done.
# Searching for "Firehouse" by Love Of A Lifetime...
# Done.
# Searching for "Sad Cafe" by La-Di-Da...
# Done.
# Done.
# Done.
# Done.
# 188639    [Verse 1]\nLipstick junkie\nDebunk the all in ...
# 246920    {Instrumental Lead In}\n\nOn a morning from a ...
# 213705    [Intro: Puff]\nBad Boy\nWe ain't gon' stop\n\n...
# 85737     It may not or maybe a no concern of the Guinne...
# 124890    [Verse 1: Tyga]\nYeah, ah, bye baby, they ain'...
# 47074     I guess the time was right for us to say\nWe'd...
# 199264    Well, I've run through rainbows\nAnd castles o...
# 106124    How come every time we meet?\nYou got lots of ...
# 273289    [Verse 1]\nYou and me, we made a vow\nFor bett...
# 257005    [Verse 1]\nSame bed but it feels just a little...
# dtype: object

# %%
df_bb_10
# Out:
#                                                       url      weekid  \
# 188639  http://www.billboard.com/charts/hot-100/2011-1...  2011-11-26
# 246920  http://www.billboard.com/charts/hot-100/1977-0...  1977-02-19
# 213705  http://www.billboard.com/charts/hot-100/1997-0...  1997-04-05
# 85737   http://www.billboard.com/charts/hot-100/1964-0...  1964-09-12
# 124890  http://www.billboard.com/charts/hot-100/2015-0...  2015-07-25
# 47074   http://www.billboard.com/charts/hot-100/1991-0...  1991-09-14
# 199264  http://www.billboard.com/charts/hot-100/1991-1...  1991-10-12
# 106124  http://www.billboard.com/charts/hot-100/1981-0...  1981-08-22
# 273289  http://www.billboard.com/charts/hot-100/2015-0...  2015-01-17
# 257005  http://www.billboard.com/charts/hot-100/2013-0...  2013-07-20
#
#         week_position                                 song  \
# 188639             97  The Adventures Of Rain Dance Maggie
# 246920             13                      Year Of The Cat
# 213705              1            Can't Nobody Hold Me Down
# 85737              71                      Johnny B. Goode
# 124890             77                          Do It Again
# 47074              12                   Love Of A Lifetime
# 199264             56             Sometimes (It's A Bitch)
# 106124             80                             La-Di-Da
# 273289              8                 I'm Not The Only One
# 257005             29                  When I Was Your Man
#
#                                    performer  \
# 188639                 Red Hot Chili Peppers
# 246920                            Al Stewart
# 213705           Puff Daddy (Featuring Mase)
# 85737                           Dion Di Muci
# 124890  Pia Mia Featuring Chris Brown & Tyga
# 47074                              Firehouse
# 199264                          Stevie Nicks
# 106124                              Sad Cafe
# 273289                             Sam Smith
# 257005                            Bruno Mars
#
#                                                    songid  instance  \
# 188639  The Adventures Of Rain Dance MaggieRed Hot Chi...         1
# 246920                          Year Of The CatAl Stewart         1
# 213705  Can't Nobody Hold Me DownPuff Daddy (Featuring...         1
# 85737                         Johnny B. GoodeDion Di Muci         1
# 124890    Do It AgainPia Mia Featuring Chris Brown & Tyga         1
# 47074                         Love Of A LifetimeFirehouse         1
# 199264               Sometimes (It's A Bitch)Stevie Nicks         1
# 106124                                   La-Di-DaSad Cafe         1
# 273289                      I'm Not The Only OneSam Smith         2
# 257005                      When I Was Your ManBruno Mars         3
#
#         previous_week_position  peak_position  weeks_on_chart  \
# 188639                    89.0             38              17
# 246920                    15.0             13              11
# 213705                     1.0              1              11
# 85737                     71.0             71               4
# 124890                    86.0             77               2
# 47074                     18.0             12              12
# 199264                    57.0             56               6
# 106124                    90.0             80               2
# 273289                     6.0              5              18
# 257005                    26.0              1              29
#
#                                                  songkey
# 188639  theadventuresofraindancemaggieredhotchilipeppers
# 246920                             yearofthecatalstewart
# 213705        cantnobodyholdmedownpuffdaddyfeaturingmase
# 85737                             johnnybgoodediondimuci
# 124890            doitagainpiamiafeaturingchrisbrowntyga
# 47074                           loveofalifetimefirehouse
# 199264                     sometimesitsabitchstevienicks
# 106124                                     ladidasadcafe
# 273289                           imnottheonlyonesamsmith
# 257005                          wheniwasyourmanbrunomars

# %%
from pandarallel import pandarallel
pandarallel.initialize()
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data tranfer (pipe) to transfer data between the main process and workers.

# %%
df_bb_10['lyrics'] = df_bb_10.parallel_apply(get_lyrics, axis=1)
# Out:
# Searching for "Dion Di Muci" by Johnny B. Goode...
# Searching for "Sam Smith" by I'm Not The Only One...
# Searching for "Red Hot Chili Peppers" by The Adventures Of Rain Dance Maggie...
# Searching for "Stevie Nicks" by Sometimes (It's A Bitch)...
# Done.
# Searching for "Al Stewart" by Year Of The Cat...
# Done.
# Searching for "Pia Mia Featuring Chris Brown & Tyga" by Do It Again...
# Done.
# Searching for "Sad Cafe" by La-Di-Da...
# Done.
# Searching for "Bruno Mars" by When I Was Your Man...
# Done.
# Searching for "Puff Daddy (Featuring Mase)" by Can't Nobody Hold Me Down...
# Done.
# Searching for "Firehouse" by Love Of A Lifetime...
# Done.
# Done.
# Done.
# Done.

# %%
df_bb_10
# Out:
#                                                       url      weekid  \
# 188639  http://www.billboard.com/charts/hot-100/2011-1...  2011-11-26
# 246920  http://www.billboard.com/charts/hot-100/1977-0...  1977-02-19
# 213705  http://www.billboard.com/charts/hot-100/1997-0...  1997-04-05
# 85737   http://www.billboard.com/charts/hot-100/1964-0...  1964-09-12
# 124890  http://www.billboard.com/charts/hot-100/2015-0...  2015-07-25
# 47074   http://www.billboard.com/charts/hot-100/1991-0...  1991-09-14
# 199264  http://www.billboard.com/charts/hot-100/1991-1...  1991-10-12
# 106124  http://www.billboard.com/charts/hot-100/1981-0...  1981-08-22
# 273289  http://www.billboard.com/charts/hot-100/2015-0...  2015-01-17
# 257005  http://www.billboard.com/charts/hot-100/2013-0...  2013-07-20
#
#         week_position                                 song  \
# 188639             97  The Adventures Of Rain Dance Maggie
# 246920             13                      Year Of The Cat
# 213705              1            Can't Nobody Hold Me Down
# 85737              71                      Johnny B. Goode
# 124890             77                          Do It Again
# 47074              12                   Love Of A Lifetime
# 199264             56             Sometimes (It's A Bitch)
# 106124             80                             La-Di-Da
# 273289              8                 I'm Not The Only One
# 257005             29                  When I Was Your Man
#
#                                    performer  \
# 188639                 Red Hot Chili Peppers
# 246920                            Al Stewart
# 213705           Puff Daddy (Featuring Mase)
# 85737                           Dion Di Muci
# 124890  Pia Mia Featuring Chris Brown & Tyga
# 47074                              Firehouse
# 199264                          Stevie Nicks
# 106124                              Sad Cafe
# 273289                             Sam Smith
# 257005                            Bruno Mars
#
#                                                    songid  instance  \
# 188639  The Adventures Of Rain Dance MaggieRed Hot Chi...         1
# 246920                          Year Of The CatAl Stewart         1
# 213705  Can't Nobody Hold Me DownPuff Daddy (Featuring...         1
# 85737                         Johnny B. GoodeDion Di Muci         1
# 124890    Do It AgainPia Mia Featuring Chris Brown & Tyga         1
# 47074                         Love Of A LifetimeFirehouse         1
# 199264               Sometimes (It's A Bitch)Stevie Nicks         1
# 106124                                   La-Di-DaSad Cafe         1
# 273289                      I'm Not The Only OneSam Smith         2
# 257005                      When I Was Your ManBruno Mars         3
#
#         previous_week_position  peak_position  weeks_on_chart  \
# 188639                    89.0             38              17
# 246920                    15.0             13              11
# 213705                     1.0              1              11
# 85737                     71.0             71               4
# 124890                    86.0             77               2
# 47074                     18.0             12              12
# 199264                    57.0             56               6
# 106124                    90.0             80               2
# 273289                     6.0              5              18
# 257005                    26.0              1              29
#
#                                                  songkey  \
# 188639  theadventuresofraindancemaggieredhotchilipeppers
# 246920                             yearofthecatalstewart
# 213705        cantnobodyholdmedownpuffdaddyfeaturingmase
# 85737                             johnnybgoodediondimuci
# 124890            doitagainpiamiafeaturingchrisbrowntyga
# 47074                           loveofalifetimefirehouse
# 199264                     sometimesitsabitchstevienicks
# 106124                                     ladidasadcafe
# 273289                           imnottheonlyonesamsmith
# 257005                          wheniwasyourmanbrunomars
#
#                                                    lyrics
# 188639  [Verse 1]\nLipstick junkie\nDebunk the all in ...
# 246920  {Instrumental Lead In}\n\nOn a morning from a ...
# 213705  [Intro: Puff]\nBad Boy\nWe ain't gon' stop\n\n...
# 85737   It may not or maybe a no concern of the Guinne...
# 124890  [Verse 1: Tyga]\nYeah, ah, bye baby, they ain'...
# 47074   I guess the time was right for us to say\nWe'd...
# 199264  Well, I've run through rainbows\nAnd castles o...
# 106124  How come every time we meet?\nYou got lots of ...
# 273289  [Verse 1]\nYou and me, we made a vow\nFor bett...
# 257005  [Verse 1]\nSame bed but it feels just a little...
